# %%
# %matplotlib inline
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d
import pandas as pd

# for loading wrf
from glob import glob
from netCDF4 import Dataset
import wrf

ena = {'lat': 39, 'lon': 360 - 28}

# %% [markdown]
# # Comparison of ERA5 and WRF output at ENA site for July 18, 2017 drizzling Sc case
# Location is (39N, 28W). Observation site (Santa Cruz Da Graciosa) is on NW tip of the island.

# %% [markdown]
# ### Observational sets from ARM
#
# * `enainterpolatedsonde`: time-height of atmospheric state estimated from radiosondes connected in time via surface meteorology and microwave radiometer estimated total column water vapor observations
#   * `temp`, `potential_temp`
#   * `rh`, `rh_scaled` (using MWR ... not sure which is better)
#   * `u_wind`, `v_wind`
# * `enaaafnaviwg`: atmospheric state measurements from the aircraft
# * `enarlprof`: remote sensing estimated low level temperature and humidity (Raman lidar)
#   * `cbh` (cloud base height)
# * `enadlprof`: remote sensing estimated winds (Doppler lidar)

# %%
ds_sonde = xr.open_dataset('/Users/jone003/tmp/EAGLES/arm_data/enainterpolatedsondeC1.c1.20170718.000030.nc')
ds_aaf = xr.open_dataset('/Users/jone003/Dropbox/EAGLES/arm_data/enaaafnaviwgF1.c1.20170718.083145.nc')
ds_rlprof = xr.open_dataset('/Users/jone003/Dropbox/EAGLES/arm_data/enarlprofmr2news10mC1.c0.20170718.000500.nc')
ds_dlprof = xr.open_dataset('/Users/jone003/Dropbox/EAGLES/arm_data/enadlprofwind4newsC1.c1.20170718.000035.nc')

# %%
# combine into hourly-averaged product
sonde_variables = ['temp', 'potential_temp', 'sh', 'rh', 'rh_scaled', 'u_wind', 'v_wind']
ds_obs = xr.merge([ds_sonde[sonde_variables].resample(time='1H').mean(), ds_rlprof['cbh'].resample(time='1H').mean()])
ds_obs
# Out:
# /anaconda3/lib/python3.6/site-packages/xarray/core/nanops.py:140: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# <xarray.Dataset>
# Dimensions:         (height: 332, time: 24)
# Coordinates:
#   * time            (time) datetime64[ns] 2017-07-18 ... 2017-07-18T23:00:00
#   * height          (height) float32 0.03048 0.05048 ... 40.510487 41.010487
# Data variables:
#     temp            (time, height) float32 22.19273 22.217276 ... nan nan
#     potential_temp  (time, height) float32 293.83344 294.05087 ... nan nan
#     sh              (time, height) float32 0.015636686 0.01544176 ... nan nan
#     rh              (time, height) float32 94.79914 93.27482 ... nan nan
#     rh_scaled       (time, height) float32 94.79914 93.27482 ... nan nan
#     u_wind          (time, height) float32 6.0792084 4.2391715 ... nan nan
#     v_wind          (time, height) float32 -0.12813248 -0.8111962 ... nan nan
#     cbh             (time) float32 0.3275 0.37979567 ... 1.1386427 0.9937499

# %% [markdown]
# ### WRF

# %%
wrf_output = sorted(glob('/Users/jone003/tmp/EAGLES/WRF/output_wrf/ena_2017_07_18/wrfout_d01_2017-07-1*'))
wrf_in = [Dataset(f) for f in wrf_output]

# %%
lat = wrf.getvar(wrf_in, 'lat', timeidx=wrf.ALL_TIMES, method="cat")
lon = wrf.getvar(wrf_in, 'lon', timeidx=wrf.ALL_TIMES, method='cat')
temp = wrf.getvar(wrf_in, 'tc', timeidx=wrf.ALL_TIMES, method='cat')
theta = wrf.getvar(wrf_in, 'theta', timeidx=wrf.ALL_TIMES, method='cat')
z = wrf.getvar(wrf_in, 'z', timeidx=wrf.ALL_TIMES, method='cat')
rh = wrf.getvar(wrf_in, 'rh', timeidx=wrf.ALL_TIMES, method='cat')
u = wrf.getvar(wrf_in, 'ua', timeidx=wrf.ALL_TIMES, method='cat')
v = wrf.getvar(wrf_in, 'va', timeidx=wrf.ALL_TIMES, method='cat')
cloudfrac = wrf.getvar(wrf_in, 'cloudfrac', timeidx=wrf.ALL_TIMES, method='cat')

qvapor = wrf.getvar(wrf_in, 'QVAPOR', timeidx=wrf.ALL_TIMES, method='cat')
qcloud = wrf.getvar(wrf_in, 'QCLOUD', timeidx=wrf.ALL_TIMES, method='cat')
qrain = wrf.getvar(wrf_in, 'QRAIN', timeidx=wrf.ALL_TIMES, method='cat')
qice = wrf.getvar(wrf_in, 'QICE', timeidx=wrf.ALL_TIMES, method='cat')
q = qvapor / (1 + qvapor)  # specific humidity
cld = wrf.getvar(wrf_in, 'CLDFRA', timeidx=wrf.ALL_TIMES, method='cat')

# %%
# updated version at 59, 60
ena_wrf = {'south_north': 59, 'west_east': 60}  # approx 28W, 39N

# %%
ds_wrf = xr.Dataset({'temp': temp,
                     'u_wind': u,
                     'v_wind': v,
                     'sh': q,
                     'potential_temp': theta,
                     'height': z / 1000,
                     'cloudfrac': cloudfrac,
                     'qvapor': qvapor,
                     'qcloud': qcloud,
                     'qice': qice,
                     'qrain': qrain,
                     'rh': rh,
                     'cld': cld}
                   )
ds_wrf_ena = ds_wrf.isel(**ena_wrf).sel(Time='2017-07-18')

# %% [markdown]
# ### reanalysis

# %%
ds_era = xr.open_dataset('ERA5_ENA_20170717-20170719_with_height_and_presl.nc')
ds_era
# Out:
# <xarray.Dataset>
# Dimensions:                (lat: 9, lev: 137, lon: 9, time: 72)
# Coordinates:
#   * time                   (time) datetime64[ns] 2017-07-17 ... 2017-07-19T23:00:00
#   * lat                    (lat) float32 40.0 39.75 39.5 ... 38.5 38.25 38.0
#   * lon                    (lon) float32 331.0 331.25 331.5 ... 332.75 333.0
#   * lev                    (lev) float32 1.0 2.0 3.0 4.0 ... 135.0 136.0 137.0
# Data variables:
#     TMP                    (time, lev, lat, lon) float32 ...
#     SPFH                   (time, lev, lat, lon) float32 ...
#     UGRD                   (time, lev, lat, lon) float32 ...
#     VGRD                   (time, lev, lat, lon) float32 ...
#     GP                     (time, lat, lon) float32 ...
#     NLPRES                 (time, lat, lon) float32 ...
#     initial_time0_encoded  (time) float64 ...
#     initial_time0          (time) |S18 ...
#     height                 (lev, time, lat, lon) float64 ...
#     pressure               (lev, time, lat, lon) float64 ...
# Attributes:
#     creation_date:  Thu Oct 31 10:15:54 PDT 2019
#     NCL_Version:    6.6.2
#     system:         Linux compy01.pnl.gov 3.10.0-957.5.1.el7.x86_64 #1 SMP Fr...
#     Conventions:    None
#     grib_source:    ERA5_ENA_20170717-20170719_ml.grb
#     title:          NCL: convert-GRIB-to-netCDF

# %%
zobs = ds_sonde['height']
height = ds_era['height']  # dims ('lev', 'time', 'lat', 'lon')

# %%
# optionally interpolate ds_era to same height levels as obs ds
# should make it easier to compare directly, but not really needed if just plotting
def interp_to_height(ds_era, height_obs):
    height = ds_era['height'].transpose('time', 'lev', 'lat', 'lon')  # originally (lev, time, lat, lon)
    height = height[:, ::-1, :, :]  # ordered as increasing height
    ax0 = height.dims.index('lev')
    
    var_list = [v for v in ds_era if 'lev' in ds_era[v].dims]  # time, lev, lat, lon
    
    time = ds_era.time.values
    lat = ds_era.lat.values
    lon = ds_era.lon.values
    ntime = len(time)
    nlat = len(lat)
    nlon = len(lon)
    nheight = len(height_obs)
    out_shape = (ntime, nheight, nlat, nlon)
    
    ds_out = xr.Dataset()
    ds_out['height'] = height_obs
    # easiest to just loop over columns (even if that feels dumb)
    # new output has shape time, nheight, nlat, nlon
    for v in var_list:
        print(v)
        if v == 'height':
            continue
        # note: need to reverse order so height increases
        arr_in = ds_era[v].transpose('time', 'lev', 'lat', 'lon').values[:, ::-1, :, :]
        arr_out = np.full(out_shape, np.nan)
        print(arr_out.shape)
        print(arr_in.shape)
        for jt in range(ntime):
            for jlat in range(nlat):
                for jlon in range(nlon):
                    arr_out[jt, :, jlat, jlon] = np.interp(height_obs.values,
                                                           height[jt, :, jlat, jlon],
                                                           arr_in[jt, :, jlat, jlon])
        da = xr.DataArray(arr_out, coords=[time, height_obs, lat, lon],
                          dims=['time', 'height', 'lat', 'lon'],
                          name=v,
                          attrs=ds_era[v].attrs)
        ds_out[v] = da.copy(deep=True)
    return ds_out

# %%
ds_era_height = interp_to_height(ds_era, zobs)
# ds_era_height
# Out:
# TMP
# (72, 332, 9, 9)
# (72, 137, 9, 9)
# SPFH
# (72, 332, 9, 9)
# (72, 137, 9, 9)
# UGRD
# (72, 332, 9, 9)
# (72, 137, 9, 9)
# VGRD
# (72, 332, 9, 9)
# (72, 137, 9, 9)
# height
# pressure
# (72, 332, 9, 9)
# (72, 137, 9, 9)

# %%
era_theta = ds_era_height['TMP'] * (1000 * 100 / ds_era_height['pressure']) ** (0.286)
era_theta.attrs = {'units': 'K', 'long_name': 'potential temperature'}
ds_era_height['potential_temp'] = era_theta
# ds_era_height

# %%
# for initial comparison, select lat, lon = (39, -28)
ds_era_ena = ds_era.sel(**ena, time='2017-07-18')
if 'lev' in ds_era_height:
    ds_era_height_ena = ds_era_height.drop('lev').sel(**ena, time='2017-07-18')
else:
    ds_era_height_ena = ds_era_height.sel(**ena, time='2017-07-18')

# %%
ds_era_height_ena
# Out:
# <xarray.Dataset>
# Dimensions:         (height: 332, time: 24)
# Coordinates:
#   * height          (height) float32 0.03048 0.05048 ... 40.510487 41.010487
#   * time            (time) datetime64[ns] 2017-07-18 ... 2017-07-18T23:00:00
#     lat             float32 39.0
#     lon             float32 332.0
# Data variables:
#     TMP             (time, height) float64 295.7 295.6 295.4 ... 256.8 258.6
#     SPFH            (time, height) float64 0.01567 0.01564 ... 3.723e-06
#     UGRD            (time, height) float64 8.585 9.268 9.736 ... -28.8 -30.88
#     VGRD            (time, height) float64 -1.393 -1.603 ... -7.385 -6.744
#     pressure        (time, height) float64 1.018e+05 1.016e+05 ... 284.9 267.0
#     potential_temp  (time, height) float64 294.2 294.3 ... 1.373e+03 1.408e+03

# %% [markdown]
# # Plots

# %%
# sanity check to verify regridding of era5 was reasonable
i = 0
z_obs = ds_obs.height
plt.plot(ds_obs.temp.isel(time=i), z_obs)
plt.plot(ds_era_ena.TMP.isel(time=i) - 273.15, ds_era_ena.height.isel(time=0))
plt.plot(ds_era_height_ena.TMP.isel(time=i) - 273.15, ds_era_height_ena.height,':')
plt.plot(ds_wrf_ena.temp.isel(Time=i), ds_wrf_ena.height.isel(Time=i),'--')
plt.ylim([0, 5])
plt.xlim([-5, 23])
plt.legend(['obs', 'era5', 'era5-regrid', 'WRF'])

# %%
# join era and obs:
ds1 = ds_era_height_ena.rename({'TMP': 'temp',
                                'UGRD': 'u_wind',
                                'VGRD': 'v_wind',
                                'SPFH': 'sh'}).drop(['lat', 'lon'])
if ds1['temp'].min() > 50:
    # convert to celsius
    ds1['temp'].values = ds1['temp'].values - 273.15
ds1
# Out:
# <xarray.Dataset>
# Dimensions:         (height: 332, time: 24)
# Coordinates:
#   * height          (height) float32 0.03048 0.05048 ... 40.510487 41.010487
#   * time            (time) datetime64[ns] 2017-07-18 ... 2017-07-18T23:00:00
# Data variables:
#     temp            (time, height) float64 22.55 22.42 22.28 ... -16.33 -14.51
#     sh              (time, height) float64 0.01567 0.01564 ... 3.723e-06
#     u_wind          (time, height) float64 8.585 9.268 9.736 ... -28.8 -30.88
#     v_wind          (time, height) float64 -1.393 -1.603 ... -7.385 -6.744
#     pressure        (time, height) float64 1.018e+05 1.016e+05 ... 284.9 267.0
#     potential_temp  (time, height) float64 294.2 294.3 ... 1.373e+03 1.408e+03

# %%
qcld_wrf = ds_wrf_ena.qcloud.values
is_cloud = qcld_wrf > 0
np.count_nonzero(is_cloud)
# Out:
# 42

# %%
plt.pcolor(is_cloud)

# %%
ds_wrf_ena.qcloud.plot(robust=True)

# %%
ds_rlprof['cbh'].plot()
cbh_mask = ds_rlprof['cbh'] > 0

# %%
# plot time-height of cloud fraction from WRF vs. cbh from obs
zrange = slice(0, 35)
zx = ds_wrf_ena.height.isel(bottom_top=zrange)
cldx = ds_wrf_ena.cld.isel(bottom_top=zrange)
tx = ds_wrf_ena.Time

# ds_obs.cbh

# %%
cbh.sel(time='2017-07-18T02:00:00', method='nearest')
# Out:
# <xarray.DataArray 'cbh' ()>
# array(0.3225, dtype=float32)
# Coordinates:
#     time     datetime64[ns] 2017-07-18T02:05:00
# Attributes:
#     long_name:  Cloud base height
#     units:      km
#     comment:    Height represents distance above ground level

# %%
plt.pcolormesh(tx.broadcast_like(zx), zx, cldx, vmin=0, vmax=1)

# add cloudbase height from rl_prof
cbh = ds_rlprof['cbh'].where(cbh_mask)
plt.plot(ds_rlprof.time, cbh, 'r--')
plt.colorbar()
plt.title('WRF CLDFRAC and rlprof cloudbase')
plt.xlabel('time')
plt.ylabel('height [km]')
# Out:
# Text(0, 0.5, 'height [km]')

# %%
ds_wrf_ena.cld.plot(x='Time', robust=True)

# %%
ds_wrf_ena.qvapor.plot()

# %%
ds_wrf_ena.rh.plot()

# %%
p = ds_wrf.cloudfrac.isel(low_mid_high=0).plot(col='Time', col_wrap=4)
for ax in p.axes.flat:
    ax.plot(ena_wrf['west_east'], ena_wrf['south_north'], 'kx')

# %%
z
# Out:
# <xarray.DataArray 'height' (Time: 31, bottom_top: 86, south_north: 120, west_east: 120)>
# array([[[[4.2099547e+00, 4.2104087e+00, 4.2098122e+00, ...,
#           4.1979461e+00, 4.1979437e+00, 4.1979604e+00],
#          [4.2098904e+00, 4.2098165e+00, 4.2097449e+00, ...,
#           4.1979003e+00, 4.1978941e+00, 4.1979012e+00],
#          [4.2098227e+00, 4.2097502e+00, 4.2096810e+00, ...,
#           4.1978531e+00, 4.1978345e+00, 4.1978335e+00],
#          ...,
#          [4.2044468e+00, 4.2043371e+00, 4.2047534e+00, ...,
#           4.1958961e+00, 4.1957989e+00, 4.1957049e+00],
#          [4.2049112e+00, 4.2048025e+00, 4.2046933e+00, ...,
#           4.1957936e+00, 4.1956949e+00, 4.1955972e+00],
#          [4.2048492e+00, 4.2047424e+00, 4.2046332e+00, ...,
#           4.1956987e+00, 4.1955967e+00, 4.1954951e+00]],
#
#         [[2.5295235e+01, 2.5295887e+01, 2.5294977e+01, ...,
#           2.5220711e+01, 2.5220600e+01, 2.5221109e+01],
#          [2.5295431e+01, 2.5295025e+01, 2.5294123e+01, ...,
#           2.5220423e+01, 2.5220276e+01, 2.5220213e+01],
#          [2.5294567e+01, 2.5294697e+01, 2.5293795e+01, ...,
#           2.5220125e+01, 2.5219919e+01, 2.5219807e+01],
#          ...,
#          [2.5269424e+01, 2.5268744e+01, 2.5268585e+01, ...,
#           2.5215239e+01, 2.5214676e+01, 2.5214123e+01],
#          [2.5269632e+01, 2.5268951e+01, 2.5268272e+01, ...,
#           2.5214157e+01, 2.5213581e+01, 2.5213020e+01],
#          [2.5269306e+01, 2.5268637e+01, 2.5267954e+01, ...,
#           2.5213636e+01, 2.5213049e+01, 2.5212469e+01]],
#
#         [[6.3343513e+01, 6.3343136e+01, 6.3342785e+01, ...,
#           6.3151722e+01, 6.3151165e+01, 6.3151344e+01],
#          [6.3343376e+01, 6.3342987e+01, 6.3340565e+01, ...,
#           6.3150978e+01, 6.3150307e+01, 6.3149849e+01],
#          [6.3342194e+01, 6.3341827e+01, 6.3339924e+01, ...,
#           6.3149689e+01, 6.3149422e+01, 6.3148838e+01],
#          ...,
#          [6.3294971e+01, 6.3293163e+01, 6.3291344e+01, ...,
#           6.3153168e+01, 6.3151817e+01, 6.3150478e+01],
#          [6.3294281e+01, 6.3292484e+01, 6.3290672e+01, ...,
#           6.3150368e+01, 6.3149502e+01, 6.3148151e+01],
#          [6.3293591e+01, 6.3291813e+01, 6.3289989e+01, ...,
#           6.3149708e+01, 6.3148315e+01, 6.3146935e+01]],
#
#         ...,
#
#         [[2.0031092e+04, 2.0031064e+04, 2.0031039e+04, ...,
#           2.0027016e+04, 2.0026965e+04, 2.0026910e+04],
#   * Time      (Time) datetime64[ns] 2017-07-17T18:00:00 ... 2017-07-19
#     datetime  (Time) datetime64[ns] 2017-07-17T18:00:00 ... 2017-07-19
# Dimensions without coordinates: bottom_top, south_north, west_east
# Attributes:
#     FieldType:    104
#     MemoryOrder:  XYZ
#     description:  model height - [MSL] (mass grid)
#     units:        m
#     stagger:
#     coordinates:  XLONG XLAT XTIME
#     projection:   LambertConformal(stand_lon=-28.030000686645508, moad_cen_la...

# %%
z = ds_obs.height

# %%
# make a long set of plots:
# all together together: 
#    fig, axes = plt.subplots(ncols=5, nrows=24, figsize=(8, 48)
# but, it looks better if they're all separate instead
z = ds1.height
xlims = (0, 125)
ylims = (0, 3)
ylab = 'height (km)'
xlab = 'Rel. Hum. (%)'
for n in range(len(ds_obs.time)):
    cb = cbh.sel(time=ds_obs.time[n], method='nearest')
    fig, ax = plt.subplots()
    ax.plot(ds_obs['rh'].isel(time=n), z)
    ax.plot(ds_wrf_ena['rh'].isel(Time=n), ds_wrf_ena.height.isel(Time=n))
    ax.set_xlim(xlims)
    ax.set_ylim(ylims)
    ax.plot(xlims, [cb, cb], 'r--')
    ax.legend(['Obs', 'WRF'], frameon=False)
    ax.set_ylabel(ylab)
    the_title = np.datetime_as_string(ds_obs.time.values[n], unit='m')
    ax.set_title(the_title)
    ax.set_xlabel(xlab)
    plt.show()

# %%
# make a long set of plots:
# all together together: 
#    fig, axes = plt.subplots(ncols=5, nrows=24, figsize=(8, 48)
# but, it looks better if they're all separate instead

save_fig = False
z = ds1.height
ylims = [0, 3]
xlims = [(0, 25), (290, 310), (0, 0.02), (0, 20), (-12, 1)]
ylab = 'height (km)'
xlab = ['T (C)', 'Pot. temp. (K)', 'specific humidity', 'u (m/s)', 'v (m/s)']
for n in range(len(ds1.time)):
    cb = cbh.sel(time=ds1.time[n], method='nearest')
    fig, axes = plt.subplots(ncols=5, nrows=1, figsize=(10, 2))
    for j, v in enumerate(['temp', 'potential_temp', 'sh', 'u_wind', 'v_wind']):
        ax = axes[j]
        ax.plot(ds1[v].isel(time=n), z)
        ax.plot(ds_obs[v].isel(time=n), z)
        ax.plot(ds_wrf_ena[v].isel(Time=n), ds_wrf_ena.height.isel(Time=n))
        ax.set_ylim(ylims)
        ax.set_xlim(xlims[j])
        # ax.plot(xlims[j], [cb, cb], 'r--')
        if (j == 0):
            ax.legend(['ERA5', 'Obs', 'WRF'], frameon=False)
        if j == 0:
            ax.set_ylabel(ylab)
        if j == 2:
            the_title = np.datetime_as_string(ds1.time.values[n], unit='m')
            ax.set_title(the_title)
        ax.set_xlabel(xlab[j])
    if save_fig:
        out_name = f'era5_v_wrf_v_obs_ena_20170718_v2_{n:02}.png'
        fig.savefig(out_name)
    plt.show()

# %%
ds_era
# Out:
# <xarray.Dataset>
# Dimensions:                (lat: 9, lev: 137, lon: 9, time: 72)
# Coordinates:
#   * time                   (time) datetime64[ns] 2017-07-17 ... 2017-07-19T23:00:00
#   * lat                    (lat) float32 40.0 39.75 39.5 ... 38.5 38.25 38.0
#   * lon                    (lon) float32 331.0 331.25 331.5 ... 332.75 333.0
#   * lev                    (lev) float32 1.0 2.0 3.0 4.0 ... 135.0 136.0 137.0
# Data variables:
#     TMP                    (time, lev, lat, lon) float32 ...
#     SPFH                   (time, lev, lat, lon) float32 ...
#     UGRD                   (time, lev, lat, lon) float32 ...
#     VGRD                   (time, lev, lat, lon) float32 ...
#     GP                     (time, lat, lon) float32 ...
#     NLPRES                 (time, lat, lon) float32 ...
#     initial_time0_encoded  (time) float64 ...
#     initial_time0          (time) |S18 ...
#     height                 (lev, time, lat, lon) float64 ...
#     pressure               (lev, time, lat, lon) float64 ...
# Attributes:
#     creation_date:  Thu Oct 31 10:15:54 PDT 2019
#     NCL_Version:    6.6.2
#     system:         Linux compy01.pnl.gov 3.10.0-957.5.1.el7.x86_64 #1 SMP Fr...
#     Conventions:    None
#     grib_source:    ERA5_ENA_20170717-20170719_ml.grb
#     title:          NCL: convert-GRIB-to-netCDF

# %% [markdown]
# # Extras

# %% [markdown]
# ## dataset contents

# %%
def print_var_info(v, ds):
    """Print relevant attribute info about variable v in dataset ds"""
    attrs = ds[v].attrs
    long_name = attrs.get('long_name', '')
    units = attrs.get('units', '')
    standard_name = attrs.get('standard_name', '')
    dims = ','.join(ds[v].dims)
    print(f'{v} ({dims}): {long_name} [{units}]\n\t{standard_name}')

# %%
for v in ds_sonde:
    print_var_info(v, ds_sonde)
# Out:
# base_time (): Base time in Epoch []
#
# time_offset (time): Time offset from base_time []
#
# precip (time): Precipitation [mm]
# 	lwe_thickness_of_precipitation_amount
# qc_precip (time): Quality check results on field: Precipitation [unitless]
#
# temp (time,height): Temperature [degC]
# 	air_temperature
# qc_temp (time,height): Quality check results on field: Temperature [unitless]
#
# source_temp (time,height): Source for field: Temperature [unitless]
#
# rh (time,height): Relative humidity [%]
# 	relative_humidity
# qc_rh (time,height): Quality check results on field: Relative humidity [unitless]
#
# source_rh (time,height): Source for field: Relative humidity [unitless]
#
# vap_pres (time,height): Vapor pressure [kPa]
# 	water_vapor_partial_pressure_in_air
# qc_vap_pres (time,height): Quality check results on field: Vapor pressure [unitless]
#
# bar_pres (time,height): Barometric pressure [kPa]
# 	air_pressure
# qc_bar_pres (time,height): Quality check results on field: Barometric pressure [unitless]
#
# source_bar_pres (time,height): Source for field: Barometric pressure [unitless]
#
# wspd (time,height): Wind speed [m s-1]
# 	wind_speed
# qc_wspd (time,height): Quality check results on field: Wind speed [unitless]
#
# wdir (time,height): Wind direction [degree]
# 	wind_to_direction
# qc_wdir (time,height): Quality check results on field: Wind direction [unitless]
#
# u_wind (time,height): Eastward wind component [m s-1]
# 	eastward_wind
# qc_u_wind (time,height): Quality check results on field: Eastward wind component [unitless]
#
# source_u_wind (time,height): Source for field: Eastward wind component [unitless]
#
# v_wind (time,height): Northward wind component [m s-1]
# 	northward_wind
# qc_v_wind (time,height): Quality check results on field: Northward wind component [unitless]
#
# source_v_wind (time,height): Source for field: Northward wind component [unitless]
#
# dp (time,height): Dewpoint temperature [degC]
# 	dew_point_temperature
# qc_dp (time,height): Quality check results on field: Dewpoint temperature [unitless]
#
# source_dp (time,height): Source for field: Dewpoint temperature [unitless]
#
# potential_temp (time,height): Potential temperature [K]
# 	air_potential_temperature
# qc_potential_temp (time,height): Quality check results on field: Potential temperature [unitless]
#
# sh (time,height): Specific humidity [g/g]
# 	specific_humidity
# qc_sh (time,height): Quality check results on field: Specific humidity [unitless]
#
# rh_scaled (time,height): Relative humidity scaled using MWR [%]
#
# qc_rh_scaled (time,height): Quality check results on field: Relative humidity scaled using MWR [unitless]
#
# aqc_rh_scaled (time,height): Ancillary quality check results on field: Relative humidity scaled using MWR [unitless]
#
# vapor_source (time,height): Source of the MWR data used to produce: rh_scaled [unitless]
#
# lat (): North latitude [degree_N]
# 	latitude
# lon (): East longitude [degree_E]
# 	longitude
# alt (): Altitude above mean sea level [m]
# 	altitude

# %%
for v in ds_aaf:
    print_var_info(v, ds_aaf)
# Out:
# base_time (): Base time in Epoch []
#
# time_offset (time): Time offset from base_time []
#
# wgs_alt (time): Altitude above the ellipsoid based on WGS-84 [m]
# 	altitude
# press_alt (time): Altitude calculated from US standard atmospheric tables [m]
# 	altitude
# radar_alt (time): Altitude calculated using GPS altitude and position with the Digital Terrain Elevation Data sets from NGA [m]
# 	altitude
# ground_speed (time): Platform speed over the ground [m/s]
# 	platform_speed_wrt_ground
# true_airspeed (time): Platform airspeed through the air [m/s]
# 	platform_speed_wrt_air
# indicated_airspeed (time): Platform airspeed calculated based on the TAS and static temperature measured by Aimms-20 [m/s]
# 	platform_speed_wrt_air
# mach_number (time): Ratio of the speed of the aircraft to the speed of sound [unitless]
#
# vertical_velocity (time): Platform vertical velocity defined in the body frame [m/s]
#
# true_heading (time): Platform direction with respect to true north [degree]
# 	platform_azimuth_angle
# track (time): Platform path angle from true north [degree]
#
# drift (time): Angle of between true heading and track [degree]
#
# pitch (time): Pitch angle of platform [degree]
# 	platform_pitch_angle
# roll (time): Roll angle of platform [degree]
# 	platform_roll_angle
# side_slip (time): Direction of wind relative to true heading [degree]
#
# angle_of_attack (time): Direction of wind relative to aircraft pitch [degree]
#
# ambient_temp (time): Temperature of ambient air [degC]
# 	air_temperature
# dewpoint_temperature (time): Dewpoint temperature [degC]
# 	dew_point_temperature
# total_temp (time): Total temperature [degC]
#
# static_pressure (time): Static pressure [hPa]
#
# dynamic_pressure (time): Dynamic pressure [hPa]
#
# cabin_pressure (time): Cabin pressure [hPa]
#
# wind_speed (time): Wind speed [m/s]
# 	wind_speed
# wind_direction (time): Wind direction [degree]
# 	wind_from_direction
# vert_wind_speed (time): Vertical wind speed [m/s]
# 	upward_air_velocity
# solar_zenith_ground (time): Solar zenith [degree]
# 	solar_zenith_angle
# sun_elev_aircraft (time): Sun elevation at aircraft [degree]
# 	solar_zenith_angle
# sun_azimuth_ground (time): Sun azimuth at ground level [degree]
# 	solar_azimuth_angle
# sun_azimuth_aircraft (time): Sun azimuth at aircraft [degree]
# 	solar_azimuth_angle
# qc_flag (time): Quality check flag [unitless]
#
# flag_ac (time): Maneuver flag [unitless]
#
# relative_humidity_water (time): Relative humidity relative to water [%]
#
# relative_humidity_ice (time): Relative humidity relative to ice [%]
#
# potential_temperature (time): Potential temperature calculated from ambient temperature and pressure [degC]
# 	air_potential_temperature
# cabin_temperature (time): Cabin temperature [degC]
#
# leg_number (time): Number of flight leg aircraft is on [unitless]
#
# lat (time): North latitude [degree_N]
# 	latitude
# lon (time): East longitude [degree_E]
# 	longitude
# alt (time): Altitude above mean sea level [m]
# 	altitude

# %%
for v in ds_rlprof:
    print_var_info(v, ds_rlprof)
# Out:
# base_time (): Base time in Epoch []
#
# time_offset (time): Time offset from base_time []
#
# time_bounds (time,bound): Time cell bounds []
#
# height_bounds (height,bound): Height cell bounds []
#
# cbh (time): Cloud base height [km]
#
# time_sonde (time): Radiosonde time flag [1]
#
# temp_sonde (time,height): Temperature from the radiosonde [K]
#
# pres_sonde (time,height): Pressure from the radiosonde [mb]
#
# mr_sonde (time,height): Water vapor mixing ratio from the radiosonde [g/kg]
#
# n2_trans_mol (time,height): One-way transmission due to molecular extinction at N2 wavelength [1]
#
# h2o_trans_mol (time,height): One-way transmission due to molecular extinction at H2O wavelength [1]
#
# mr_lo_cal (time,height): Low channel water vapor mixing ratio calibration [g/kg]
#
# mr_lo (time,height): Low channel water vapor mixing ratio [g/kg]
#
# mr_lo_err (time,height): Low channel water vapor mixing ratio error [g/kg]
#
# mr_hi_cal (time,height): High channel water vapor mixing ratio calibration [g/kg]
#
# mr_hi (time,height): High channel water vapor mixing ratio [g/kg]
#
# mr_hi_err (time,height): High channel water vapor mixing ratio error [g/kg]
#
# mr_merged (time,height): High and Low merged water vapor mixing ratio [g/kg]
#
# mr_merged_err (time,height): High and Low merged water vapor mixing ratio error [g/kg]
#
# lat (): North latitude [degree_N]
# 	latitude
# lon (): East longitude [degree_E]
# 	longitude
# alt (): Altitude above mean sea level [m]
# 	altitude

# %%
for v in ds_dlprof:
    print_var_info(v, ds_sonde)
# Out:
# base_time (): Base time in Epoch []
#
# time_offset (time): Time offset from base_time []
#
# time_bounds (time,bound):  []
#
# scan_duration (time): PPI scan duration [second]
#
# elevation_angle (time): Beam elevation angle [degree]
#
# nbeams (time): Number of beams (azimuth angles) used in wind vector estimation [unitless]
#
# u (time,height): Eastward component of wind vector [m/s]
#
# u_error (time,height): Estimated error in eastward component of wind vector [m/s]
#
# v (time,height): Northward component of wind vector [m/s]
#
# v_error (time,height): Estimated error in northward component of wind vector [m/s]
#
# w (time,height): Vertical component of wind vector [m/s]
#
# w_error (time,height): Estimated error in vertical component of wind vector [m/s]
#
# wind_speed (time,height): Wind speed [m/s]
#
# wind_speed_error (time,height): Wind speed error [m/s]
#
# wind_direction (time,height): Wind direction [degree]
#
# wind_direction_error (time,height): Wind direction error [degree]
#
# residual (time,height): Fit residual [m/s]
#
# correlation (time,height): Fit correlation coefficient [unitless]
#
# mean_snr (time,height): Signal to noise ratio averaged over nbeams [unitless]
#
# snr_threshold (): SNR threshold [unitless]
#
# met_wspd (time): Vector mean surface wind speed from MET [m/s]
#
# met_wdir (time): Vector mean surface wind direction from MET [degree]
#
# met_spr (time): Mean surface precipitation rate during averaging period from MET [mm/hr]
#
# met_spr_min (time): Minimum surface precipitation rate during averaging period from MET [mm/hr]
#
# met_spr_max (time): Maximum surface precipitation rate during averaging period from MET [mm/hr]
#
# met_dt (): Averaging period length used for MET data [second]
#
# met_lat (): MET latitude [degree_N]
# 	latitude
# met_lon (): MET longitude [degree_E]
# 	longitude
# met_alt (): MET altitude [m]
# 	altitude
# lat (): North latitude [degree_N]
# 	latitude
# lon (): East longitude [degree_E]
# 	longitude
# alt (): Altitude above mean sea level [m]
# 	altitude

# %%
print(ds_sonde)
# Out:
# <xarray.Dataset>
# Dimensions:            (height: 332, time: 1440)
# Coordinates:
#   * time               (time) datetime64[ns] 2017-07-18T00:00:30 ... 2017-07-18T23:59:30
#   * height             (height) float32 0.03048 0.05048 ... 40.510487 41.010487
# Data variables:
#     base_time          datetime64[ns] ...
#     time_offset        (time) datetime64[ns] ...
#     precip             (time) float32 ...
#     qc_precip          (time) int32 ...
#     temp               (time, height) float32 ...
#     qc_temp            (time, height) int32 ...
#     source_temp        (time, height) float64 ...
#     rh                 (time, height) float32 ...
#     qc_rh              (time, height) int32 ...
#     source_rh          (time, height) float64 ...
#     vap_pres           (time, height) float32 ...
#     qc_vap_pres        (time, height) int32 ...
#     bar_pres           (time, height) float32 ...
#     qc_bar_pres        (time, height) int32 ...
#     source_bar_pres    (time, height) float64 ...
#     wspd               (time, height) float32 ...
#     qc_wspd            (time, height) int32 ...
#     wdir               (time, height) float32 ...
#     qc_wdir            (time, height) int32 ...
#     u_wind             (time, height) float32 ...
#     qc_u_wind          (time, height) int32 ...
#     source_u_wind      (time, height) float64 ...
#     v_wind             (time, height) float32 ...
#     qc_v_wind          (time, height) int32 ...
#     source_v_wind      (time, height) float64 ...
#     dp                 (time, height) float32 ...
#     qc_dp              (time, height) int32 ...
#     source_dp          (time, height) float64 ...
#     potential_temp     (time, height) float32 ...
#     qc_potential_temp  (time, height) int32 ...
#     sh                 (time, height) float32 ...
#     qc_sh              (time, height) int32 ...
#     rh_scaled          (time, height) float32 ...
#     qc_rh_scaled       (time, height) int32 ...
#     aqc_rh_scaled      (time, height) int32 ...
#     vapor_source       (time, height) int32 ...
#     lat                float32 ...
#     lon                float32 ...
#     alt                float32 ...
# Attributes:
#     command_line:          idl -D 0 -R -n interpolatedsonde -s ena -f C1 -b 2...
#     Conventions:           ARM-1.1
#     process_version:       vap-interpolatedsonde-6.6-0.el6
#     input_datastreams:     enagriddedsondeC1.c0 : 2.2 : 20170716.000030-20170...
#     dod_version:           interpolatedsonde-c1-4.0
#     site_id:               ena
#     platform_id:           interpolatedsonde
#     facility_id:           C1
#     data_level:            c1
#     location_description:  Eastern North Atlantic (ENA), Graciosa Island, Azores
#     datastream:            enainterpolatedsondeC1.c1
#     doi:                   10.5439/1095316
#     history:               created by user dsmgr on machine ruby at 2017-07-2...

# %%
print(ds_aaf)
# Out:
# <xarray.Dataset>
# Dimensions:                  (time: 12762)
# Coordinates:
#   * time                     (time) datetime64[ns] 2017-07-18T08:31:45 ... 2017-07-18T12:04:26
# Data variables:
#     base_time                datetime64[ns] ...
#     time_offset              (time) datetime64[ns] ...
#     wgs_alt                  (time) float32 ...
#     press_alt                (time) float32 ...
#     radar_alt                (time) float32 ...
#     ground_speed             (time) float32 ...
#     true_airspeed            (time) float32 ...
#     indicated_airspeed       (time) float32 ...
#     mach_number              (time) float32 ...
#     vertical_velocity        (time) float32 ...
#     true_heading             (time) float32 ...
#     track                    (time) float32 ...
#     drift                    (time) float32 ...
#     pitch                    (time) float32 ...
#     roll                     (time) float32 ...
#     side_slip                (time) float32 ...
#     angle_of_attack          (time) float32 ...
#     ambient_temp             (time) float32 ...
#     dewpoint_temperature     (time) float32 ...
#     total_temp               (time) float32 ...
#     static_pressure          (time) float32 ...
#     dynamic_pressure         (time) float32 ...
#     cabin_pressure           (time) float32 ...
#     wind_speed               (time) float32 ...
#     wind_direction           (time) float32 ...
#     vert_wind_speed          (time) float32 ...
#     solar_zenith_ground      (time) float32 ...
#     sun_elev_aircraft        (time) float32 ...
#     sun_azimuth_ground       (time) float32 ...
#     sun_azimuth_aircraft     (time) float32 ...
#     qc_flag                  (time) int32 ...
#     flag_ac                  (time) float64 ...
#     relative_humidity_water  (time) float32 ...
#     relative_humidity_ice    (time) float32 ...
#     potential_temperature    (time) float32 ...
#     cabin_temperature        (time) float32 ...
#     leg_number               (time) float64 ...
#     lat                      (time) float32 ...
#     lon                      (time) float32 ...
#     alt                      (time) float32 ...
# Attributes:
#     command_line:          aafnaviwg_ingest -s ena -f F1 -D
#     Conventions:           ARM-1.2
#     process_version:       ingest-aafnaviwg-1.0-0.el6
#     dod_version:           aafnaviwg-c1-1.0
#     input_datastreams:     N/A
#     site_id:               ena
#     platform_id:           aafnaviwg
#     facility_id:           F1
#     data_level:            c1
#     location_description:  Eastern North Atlantic (ENA), Gulfstream 159 ("G1"...
#     datastream:            enaaafnaviwgF1.c1
#     doi:                   10.5439/1375937
#     history:               created by user dsmgr on machine ruby at 2017-11-2...

# %%
print(ds_rlprof)
# Out:
# <xarray.Dataset>
# Dimensions:        (bound: 2, height: 299, time: 144)
# Coordinates:
#   * time           (time) datetime64[ns] 2017-07-16T00:05:00 ... 2017-07-16T23:55:00
#   * height         (height) float32 0.03 0.089999996 0.14999999 ... 17.85 17.91
# Dimensions without coordinates: bound
# Data variables:
#     base_time      datetime64[ns] ...
#     time_offset    (time) datetime64[ns] ...
#     time_bounds    (time, bound) datetime64[ns] ...
#     height_bounds  (height, bound) float32 ...
#     cbh            (time) float32 ...
#     time_sonde     (time) int8 ...
#     temp_sonde     (time, height) float32 ...
#     pres_sonde     (time, height) float32 ...
#     mr_sonde       (time, height) float32 ...
#     n2_trans_mol   (time, height) float32 ...
#     h2o_trans_mol  (time, height) float32 ...
#     mr_lo_cal      (time, height) float32 ...
#     mr_lo          (time, height) float32 ...
#     mr_lo_err      (time, height) float32 ...
#     mr_hi_cal      (time, height) float32 ...
#     mr_hi          (time, height) float32 ...
#     mr_hi_err      (time, height) float32 ...
#     mr_merged      (time, height) float32 ...
#     mr_merged_err  (time, height) float32 ...
#     lat            float32 ...
#     lon            float32 ...
#     alt            float32 ...
# Attributes:
#     Conventions:           ARM-1.2
#     n2_wavelength:         386.7 nm
#     h2o_wavelength:        407.5 nm
#     transmit_wavelength:   354.7 nm
#     command_line:          idl -R -n rlprof2_mr -n rlprof2_mr -R -D 2 -t 10 -...
#     process_version:       vap-rlprof2_mr-1.1-0.el6
#     dod_version:           rlprofmr2news10m-c0-1.1
#     platform_id:           rlprofmr2news10m
#     site_id:               ena
#     facility_id:           C1
#     data_level:            c0
#     doi:                   10.5439/1415137
#     merge_range:           2.00km to 1.20km
#     location_description:  Eastern North Atlantic (ENA), Graciosa Island, Azores
#     input_datastreams:     enarlprofmrtempcalC1.c0 : 1.0 : 20170715.053557-20...
#     datastream:            enarlprofmr2news10mC1.c0
#     history:               created by user sivaraman on machine chalk at 2018...

# %%
print(ds_dlprof)
# Out:
# <xarray.Dataset>
# Dimensions:               (bound: 2, height: 164, time: 96)
# Coordinates:
#   * time                  (time) datetime64[ns] 2017-07-18T00:00:35.716050 ... 2017-07-18T23:45:23.753642
#   * height                (height) float32 90.93267 116.91344 ... 4325.797
# Dimensions without coordinates: bound
# Data variables:
#     base_time             datetime64[ns] ...
#     time_offset           (time) datetime64[ns] ...
#     time_bounds           (time, bound) datetime64[ns] ...
#     scan_duration         (time) float32 ...
#     elevation_angle       (time) float32 ...
#     nbeams                (time) int16 ...
#     u                     (time, height) float32 ...
#     u_error               (time, height) float32 ...
#     v                     (time, height) float32 ...
#     v_error               (time, height) float32 ...
#     w                     (time, height) float32 ...
#     w_error               (time, height) float32 ...
#     wind_speed            (time, height) float32 ...
#     wind_speed_error      (time, height) float32 ...
#     wind_direction        (time, height) float32 ...
#     wind_direction_error  (time, height) float32 ...
#     residual              (time, height) float32 ...
#     correlation           (time, height) float32 ...
#     mean_snr              (time, height) float32 ...
#     snr_threshold         float32 ...
#     met_wspd              (time) float32 ...
#     met_wdir              (time) float32 ...
#     met_spr               (time) float32 ...
#     met_spr_min           (time) float32 ...
#     met_spr_max           (time) float32 ...
#     met_dt                float32 ...
#     met_lat               float32 ...
#     met_lon               float32 ...
#     met_alt               float32 ...
#     lat                   float32 ...
#     lon                   float32 ...
#     alt                   float32 ...
# Attributes:
#     process_version:       vap-dlprof_wind-0.8-0.el6
#     command_line:          idl -R -n dlprof_wind -s ena -f C1 -d 20170718
#     dod_version:           dlprofwind4news-c1-1.0
#     Conventions:           ARM-1.1
#     site_id:               ena
#     platform_id:           dlprofwind4news
#     location_description:  Eastern North Atlantic (ENA), Graciosa Island, Azores
#     datastream:            enadlprofwind4newsC1.c1
#     data_level:            c1
#     facility_id:           C1
#     input_datastreams:     enadlppiC1.b1 : 2.14 : 20170718.000016-20170718.23...
#     dlat:                  39.09118
#     dlon:                  -28.02682
#     serial_number:         0514-84
#     doi:                   DOI:10.5439/1178582
#     doi_url:               http://dx.doi.org/10.5439/1178582
#     history:               created by user dsmgr on machine ruby at 2017-07-1...
